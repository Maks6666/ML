# %% [markdown]
# <a href="https://colab.research.google.com/github/Maks6666/ML/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%BD%D0%B0_%D0%B0%D0%BD%D0%B0%D0%BB%D1%96%D0%B7_%D0%B4%D0%B0%D0%BD%D0%B8%D1%852_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module2/data/weatherHistory.csv")

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# ...

# %%
df.shape
# Out:
# (96453, 11)

# %% [markdown]
# # Завдання 1
# Виведіть основні числові характеристики для числових ознак. Що потрібно зробити з стовпчиком `Loud Cover`?

# %%
df.describe(include="number")
df = df.drop("Loud Cover", axis="columns")

# %%
df.describe(include="number")
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count       96453.000000            96453.000000     96453.000000
# mean           10.810640              187.509232        10.347325
# std             6.913571              107.383428         4.192123
# min             0.000000                0.000000         0.000000
# ...

# %% [markdown]
# # Завдання 2
# Подивіться на отриману таблицю, особливо на характеристики `min` та `max`, для яких ознак потрібно побудувати ящики з вусами в першу чергу? Для решти намалюйте гістограми.

# %%
columns_to_plot = ['Temperature (C)', 'Apparent Temperature (C)', 'Wind Speed (km/h)', 'Pressure (millibars)']
for i in columns_to_plot:
  df[[i]].plot(kind='box', vert=False, figsize=(14,6))

# %%
ax = df["Humidity"].plot(kind='hist', bins=30, figsize=(14,6))
plt.title("Humidity")
plt.show()

ax = df["Wind Bearing (degrees)"].plot(kind='hist', bins=30, figsize=(14,6))
plt.title("Wind Bearing (degrees)")
plt.show()

ax = df["Visibility (km)"].plot(kind='hist', bins=30, figsize=(14,6))
plt.title("Visibility (km)")
plt.show()

# %% [markdown]
# # Завдання 3
# Чи потрібно застосувати квантильний алгоритм для видалення викидів? Якщо так то застосуйте, інакше, що на вашу думку потрібно зробити?

# %%
def remove_outliers(df, column_name):
  column = df[column_name]

  q1 = column.quantile(q=0.25)
  q3 = column.quantile(q=0.75)

  iqr = q3 - q1

  lower = q1 - 1.5*iqr
  upper = q3 + 1.5*iqr

  mask = (column >= lower) & (column <= upper)

  return df[mask]


df_1 = df.copy()
for col_name in columns_to_plot:
  if df_1.dtypes[col_name] in ("object", ):
    continue

  df_1 = remove_outliers(df_1, col_name)

df_1.shape
# Out:
# (89206, 11)

# %% [markdown]
# # Завдання 4
# Намалюйте матрицю кореляцій. Для найбільш корельованих ознак намалюйте точкову діаграму

# %%
df_t = df.drop(["Formatted Date", "Summary", "Precip Type", "Daily Summary"], axis="columns")
corr = df_t.corr(method='pearson')
corr
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# Humidity                          -0.224951                0.000735
# Wind Speed (km/h)                  1.000000                0.103822
# ...

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)

# %%
df_t.plot(kind='scatter', x='Temperature (C)', y='Apparent Temperature (C)', figsize=(6,6))
# Out:
# <Axes: xlabel='Temperature (C)', ylabel='Apparent Temperature (C)'>

# %% [markdown]
# # Завдання 5
# Виведіть характеристики для категоріальних ознак

# %%
df.describe(include="object")
# Out:
#                        Formatted Date        Summary Precip Type  \
# count                           96453          96453       95936
# unique                          96429             27           2
# top     2010-08-02 00:00:00.000 +0200  Partly Cloudy        rain
# freq                                2          31733       85224
#
#                             Daily Summary
# count                               96453
# unique                                214
# top     Mostly cloudy throughout the day.
# freq                                20085

# %% [markdown]
# # Завдання 6
# Виведіть групові ящики з вусами по одній(або декількох) категоріальних ознак. Що по них можна сказати?

# %%
cat_columns = ["Formatted Date", "Summary", "Precip Type", "Daily Summary"]

ax = df[["Summary", 'Temperature (C)']].boxplot(by='Temperature (C)', figsize=(10,6))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-e33f46eac312> in <cell line: 3>()
#       1 cat_columns = ["Formatted Date", "Summary", "Precip Type", "Daily Summary"]
#       2
# ----> 3 ax = df[["Summary", 'Temperature (C)']].boxplot(by='Temperature (C)', figsize=(10,6))
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     505 ):
#     506     plot_backend = _get_plot_backend(backend)
# --> 507     return plot_backend.boxplot_frame(
#     508         self,
#     509         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     467     import matplotlib.pyplot as plt
#     468
# ...
